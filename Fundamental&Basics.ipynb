# %%
# Q1
print('Hi sidhant ,How are yoyu')
# Out:
# Hi sidhant ,How are yoyu

# %%
# Q2
x='Sidhant is likely to have a knee injury!'
print(x)
# Out:
# Sidhant is likely to have a knee injury!

# %%
# Q3
x=2
y=3
print(x+y)
# Out:
# 5

# %%
#Q4
x=5
y=7
print(x-y)
# Out:
# -2

# %%
#Q5
x=2
y=3
print(x*y)
# Out:
# 6

# %%
#Q6
x=2
y=3
print(x/y)
# Out:
# 0.6666666666666666

# %%
#Q7
number=int(input('Enter the number='))
digit=number%10
print(digit)
# Out:
# 2

# %%
#Q8
number=int(input('Enter the number='))
first_dig=number//10
second_dig=number%10
sum_digit=first_dig+second_dig
print(sum_digit)
# Out:
# 3

# %%
#Q9
number=int(input('Enter the number:'))
first_dig=number//100
second_dig=(number//10)%10
third_dig=number%10
sum_dig=first_dig+second_dig+third_dig
print(sum_dig)
# Out:
# 3

# %%
#Q10
number=int(input('Enter the number:'))
first_dig=number//1000
second_dig=(number//100)%10
third_dig=(number//10)%10
fourth_dig=number%10
sum_dig=first_dig+second_dig+third_dig+fourth_dig
print(sum_dig)
# Out:
# 3

# %%
# Q11
number=int(input('Enter the number:'))
first_dig=number%10
second_dig=(number//10)%10
third_dig=(number//100)%10
fourth_dig=(number//1000)%10
reverse_dig=first_dig*1000+second_dig*100+third_dig*10+fourth_dig
print(reverse_dig)
# Out:
# 2100

# %%
#Q12
a=int(input("Enter a number:"))
b=int(input("Enter the number:"))
print(a)
print(b)

temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 12
# 12
# 12
# 12

# %%
#Q13
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
print(a)
print(b)
a,b=b,a
print(a)
print(b)
# Out:
# 12
# 12
# 12
# 12

# %%
#Q14
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
c=int(input("Enter the number:"))
avg=a+b+c/3
print(avg)
# Out:
# 28.0

# %%
#Q15
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
c=int(input("Enter the number:"))
t_m=a+b+c
perc=t_m/3*100
print(a,b,c)
print(t_m)
print(perc)
# Out:
# 12 12 12
# 36
# 1200.0

# %%
5*4+56+(288**2)/288*2
# Out:
# 652.0

# %%
10+2**(3*3)
# Out:
# 522

# %%
#Q17
a=30
b=10

a=a^b
b=a^b
a=a^b

print(a)
print(b)
# Out:
# 10
# 30

# %% [markdown]
# <H2>Formula Based Problems<H2>

# %%
#Q1
pi=3.14
r=int(input('Enter the radius of the circle :'))

Area_of_the_circle=pi*((r)**2)
print(Area_of_the_circle)
# Out:
# 452.16

# %%
# Q2. Find circumference of circle
pi=3.14
r=int(input('Enter the radius of the circle :'))

Circumfer=2*pi*r
print(Circumfer)
# Out:
# 75.36

# %%
# Q3. Calculate area of rectangle
l=int(input("length of the rectange="))
b=int(input("breadth of the rectange="))

area=l*b

print(area)
# Out:
# 736

# %%
#Q4. Calculate volume of sphere

pi=3.14
r=int(input('Enter the radius of the circle :'))

vol=4/3*pi*((r)**3)
print(vol)
# Out:
# 332869.30666666664

# %%
# Q5. Find surface area of sphere
pi=3.14
r=int(input('Enter the radius of the circle :'))

area=2/3*pi*((r)**2)
print(area)
# Out:
# 301.44

# %%
# Q6. Find area of square
side=int(input("The side of the square is="))

area=(side**2)

print(area)
# Out:
# 529

# %%
#Q5. Find area of right angle triangle

base=int(input("Base of the triangle is="))
height=int(input("Height of the triangle is="))

area=1/2*base*height
print(area)
# Out:
# 968.0

# %%
#Q8. Find area of equilateral triangle
side=int(input("The side of thetriangle is="))

area=(((3**0.5)/2)*(side**2))
print(area)
# Out:
# 1676.6251817266732

# %%
# Q9. Find perimeter of rectangle
l=int(input("length of the rectange="))
b=int(input("breadth of the rectange="))

peri=2*(l+b)
print(peri)
# Out:
# 176

# %%
#Q10. Find area of triangle
base=int(input("Base of the triangle is="))
height=int(input("Height of the triangle is="))

area=1/2*base*height
print(area)
# Out:
# 72.0

# %%
#Q11. Find simple interest
P=int(input("Enter the principal amount="))
R=int(input("Enter the rate of intrest="))
T=int(input("Enter the time period ="))

I=P*R*T/100
A=P+I

print(A)
# Out:
# 30000.0

# %%
#Q12. Find compound interest
P=int(input("Enter the principal amount="))
R=int(input("Enter the rate of intrest="))
T=int(input("Enter the time period ="))

A=P*((1+R/100)**T)
Comp_Inter=A-P
print(Comp_Inter)
# Out:
# 5525.631250000006

# %%
#Q13 Convert days into years
Days=int(input("Enter the no of days="))
Years=Days/365
print(Years)
# Out:
# 1.2465753424657535

# %%
#Q14 Fahrenheit to Celsius conversion
F=int(input("Enter the degree in Faranhite="))
C=(F-32)*5/9
print(C)
# Out:
# 260.0

# %% [markdown]
# <H2>Decision & Loop Control

# %%
#Q1 Check number is less than 10
a=int(input("Enter the number="))
if a>10:
    print('The no is greater than 10')
else:
    print('The no is less than 10')
# Out:
# The no is less than 10

# %%
# 2. Check numbers are equivalent
a=int(input("Enter the number="))
b=int(input("Enter the number="))
if a==b:
    print('The number are equal')
else:
    print('The number are not equal')
# Out:
# The number are equal

# %%
# 3. Check voting eligibility
age=int(input('Enter the number='))
if age>18:
    print('You are eligible to vote')
else:
    print("you are not eligible to vote")
# Out:
# You are eligible to vote

# %%
#4  Check if number is even or odd
num=int(input('Enter a number='))
if num%2==0:
    print('The no is even')
else:
    print('the no is odd')
# Out:
# the no is odd

# %%
#5 Enter three angles & check if it is a triangle
a1=int(input('Enter the angle a1='))
a2=int(input('Enter the angle a2='))
a3=int(input('Enter the angle a3='))
if a1+a2+a3==180:
    print('The Figure must be triangle')
else:
    print('The Figure is not triangle')
# Out:
# The Figure must be triangle

# %%
#6 Find total marks & percentage
s1=int(input('Enter the angle s1='))
s2=int(input('Enter the angle s2='))
s3=int(input('Enter the angle s3='))
s4=int(input('Enter the angle s4='))
totalobt=s1+s2+s3+s4
sumtotal=400
perc=totalobt/sumtotal*100
print(perc)
# Out:
# 91.0

# %%
# 7. Check for leap year
year=int(input('Enter the year='))
if year%4==0 & year%400==0:
    print('Year is leap year')
else:
    print('year is not leap year')
# Out:
# Year is leap year

# %%
#8 Check number is +ve, -ve or zero
num=int(input('Enter the number'))
if num>0:
    print('The no is positive')
elif num<0:
    print('The no is negative')
else :
    print('The no is 0')
# Out:
# The no is 0

# %%
# Largest amongst three numbers
num1=int(input('Enter the number'))
num2=int(input('Enter the number'))
num3=int(input('Enter the number'))
print(num1)
print(num2)
print(num3)
if num1>num2 & num2>num3:
    print('Num1 is greater than num2,num3')
elif num2>num3 & num3>num1:
    print('Num2 is greater than num1,num3')
else:
    print('num3 is greater than num1 ,num2')
# Out:
# 29
# 19
# 17
# Num1 is greater than num2,num3

# %%
# Print grade of employee
perfomperc=int(input('Enter the no of'))
if perfomperc>=90:
    print('The Grade is A')
elif perfomperc>=80 & perfomperc<=89:
    print('The Grade is B')
elif perfomperc>=70 & perfomperc<=79:
    print('The Grade is C')
elif perfomperc>=60 & perfomperc<=69:
    print('The Grade is D')
# Out:
# The Grade is B

# %%
# Print Color Name
code=int(input('Enter the code:'))
if code==1:
    print('The color is green')
elif code ==2:
    print('The color is orange')
elif code==3:
    print('The color is red')
elif code==4:
    print('The color is yellow')
# Out:
# The color is orange

# %%
# Print gross salary of employee
base=int(input('Enter the base salary'))
if base<10000:   
    hra=20/100*base
    da=90/100*base
    gross=hra+da+base
    print(gross)
else:
    hra=25/100*base
    da=90/100*base
    gross=hra+da+base
    print(gross)
# Out:
# 43000.0

# %%
# Print division scored by student
marks=int(input('Enter the marks scored='))
if marks>60:
    print('The division is first class')
elif marks>50 & marks<=59:
    print('The division is second class')
elif marks>40 & marks<=49:
    print('The division is third class')
else:
    print('You have Failed')
# Out:
# The division is second class

# %%
# Find greatest among 3 numbers this queestion is same as above
# Check type of triangle

a1=int(input('Enter the angle a1='))
a2=int(input('Enter the angle a2='))
a3=int(input('Enter the angle a3='))
if ((a1+a2==90) & (a3==90))|((a1+a3==90) & (a2==90))|((a3+a2==90) & (a1==90)): 
    print('The triangle is right angled triange')
elif a1==a2==a3==60:
    print('It is a equilateral tringle')
else:
    print('It is a isosscales triangle')
# Out:
# The triangle is right angled triange

# %%
# Check sum of digit greater than 10
a=int(input('Enter the no.='))
b=int(input('Enter the no.='))

if a+b>=10:
    print('Sum is greater than 10')
else:
    print('Sum is less than 10')
# Out:
# Sum is greater than 10

# %%
# Print single digit number in words
num=int(input('Enter the no='))
if num==1:
    print('One')
elif num==2:
    print('Two')
elif num==3:
    print('Three')
elif num==4:
    print('Four')
elif num==5:
    print('Five')
elif num==6:
    print('Six')
elif num==7:
    print('Seven')
elif num==8:
    print('Eight')
elif num==9:
    print('Nine')
elif num==0:
    print('Zero')
# Out:
# Two

# %%
#  Read a day of week in digit
num=int(input('Enter the no='))
if num==1:
    print('Monday')
elif num==2:
    print('Tuesday')
elif num==3:
    print('Wednesday')
elif num==4:
    print('Thursday')
elif num==5:
    print('Friday')
elif num==6:
    print('Saturday')
elif num==7:
    print('Sunday')
# Out:
# Monday

# %%
# Check alphabet is vowel or consonant
alpha=input('Enter the alphabet:')

if alpha=='a':
    print('It is vowel ')
elif alpha=='e':
    print('It is vowel ')
elif alpha=='i':
    print('It is vowel ')
elif alpha=='o':
    print('It is vowel ')
elif alpha=='u':
    print('It is vowel ')    
else:
    print('It is a consonent')
# Out:
# It is vowel

# %%
#  Right Shift & Left Shift Operations
num=int(input('Enter the choice='))
choice=int(input('Enter the choice between 1& 2='))
if choice==1:
    left_shft=num<<1
    print(f"The left shift of {num}={left_shft}")
elif choice==2:
    rig_shft=num>>1
    print(f"The left shift of {num}={rig_shft}")
else:
    print('Invalid option')
# Out:
# The left shift of 100=50

# %% [markdown]
# <H2>Patterns & Series (Advanced Loops)

# %%
#  Print number pyramid pattern
